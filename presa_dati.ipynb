# %%
#Import libraries
import serial
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Speed of sound [m/s]
c = 331.4 + 0.6*21.2

# %% [markdown]
# # MASSA 314.8

# %%
#MASSA
M1 = 314.8 #g

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_314', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df1 = pd.read_csv('arduinoB1_314')

#Time
t1 = df1['Time'].to_numpy()

#Distance 
tau1 = df1['Tau'].to_numpy()
d1 = c*tau1

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
plt.xlim(5.60*10**8, 5.80*10**8)
plt.plot(t1, tau1, '-')
plt.show()

# %% [markdown]
# # POSIZIONE DI EQUILIBRIO

# %%
#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_314_eq', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df1eq = pd.read_csv('arduinoB1_314_eq')

#Time
t1eq = df1eq['Time'].to_numpy()

#Distance 
tau1eq = df1eq['Tau'].to_numpy()
d1eq = c*tau1eq

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(8.89*10**8, 9.18*10**8)
plt.plot(t1eq, tau1eq, '-')
plt.show()

# %% [markdown]
# ### SMORZAMENTO

# %%
#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_314_sm', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 20000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df1sm = pd.read_csv('arduinoB1_314_sm')

#Time
t1sm = df1sm['Timep'].to_numpy()

#Distance 
tau1sm = df1sm['Tau'].to_numpy()
d1sm = c*tau1sm

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')#Dataframe with values read from serial monitor
df2eq = pd.read_csv('arduinoB1_474_eq')

#Time
t2eq = df2eq['Time'].to_numpy()

#Distance 
tau2eq = df2eq['Tau'].to_numpy()
d2eq = c*tau2eq
plt.xlim(1.605*10**9, 1.61*10**9)
plt.plot(t1sm, tau1sm, '.')
plt.show()

# %% [markdown]
# # MASSA 474.0

# %%
#MASSA
M2 = 474.0 #g

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_474', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df2 = pd.read_csv('arduinoB1_474')

#Time
t2 = df2['Time'].to_numpy()

#Distance 
tau2 = df2['Tau'].to_numpy()
d2 = c*tau2

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
plt.xlim(8.89*10**8, 9.18*10**8)
plt.plot(t2, tau2, '-')
plt.show()

# %% [markdown]
# ## POSIZIONE EQUILIBRIO

# %%
#MASSA
M2 = 474.0 #g

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_474_eq', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df2eq = pd.read_csv('arduinoB1_474_eq')

#Time
t2eq = df2eq['Time'].to_numpy()

#Distance 
tau2eq = df2eq['Tau'].to_numpy()
d2eq = c*tau2eq

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(8.89*10**8, 9.18*10**8)
plt.plot(t2eq, tau2eq, '-')
plt.show()

# %% [markdown]
# # 634.7

# %%
#MASSA
M3 = 634.7 #g

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_634', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df3 = pd.read_csv('arduinoB1_634')

#Time
t3 = df3['Time'].to_numpy()

#Distance 
tau3 = df3['Tau'].to_numpy()
d3 = c*tau3

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(8.89*10**8, 9.18*10**8)
plt.plot(t3, tau3, '-')
plt.show()

# %% [markdown]
# ## POSIZIONE DI EQUILIBRIO

# %%
#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_634_eq', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df3eq = pd.read_csv('arduinoB1_634_eq')

#Time
t3eq = df3eq['Time'].to_numpy()

#Distance 
tau3eq = df3eq['Tau'].to_numpy()
d3eq = c*tau3eq

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(8.89*10**8, 9.18*10**8)
plt.plot(t3eq, tau3eq, '-')
plt.show()

# %% [markdown]
# ## 793.3

# %%
#MASSA
M4 =793.3 #g

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_793', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df4 = pd.read_csv('arduinoB1_793')

#Time
t4 = df4['Time'].to_numpy()
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(8.89*10**8, 9.18*10**8)
plt.plot(t3, tau3, '-')
plt.show()
#Distance 
tau4 = df4['Tau'].to_numpy()
d4 = c*tau4

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
plt.xlim(2.05*10**9, 2.071*10**9)
plt.plot(t4, tau4, '-')
plt.show()

# %% [markdown]
# # EQUILIBRIO

# %%
#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_793_eq', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df4eq = pd.read_csv('arduinoB1_793_eq')

#Time
t4eq = df4eq['Time'].to_numpy()

#Distance 
tau4eq = df4eq['Tau'].to_numpy()
d4eq = c*tau4eq

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
plt.xlim(4.5*10**8, 4.7*10**8)
plt.plot(t4eq, tau4eq, '-')
plt.show()

# %% [markdown]
# # VELOCITA DEL SUONO

# %% [markdown]
# ### DISTANZA

# %%
#DISTANZA
d1 = 14.3 #cm incertezza grande

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_d1', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df_d1 = pd.read_csv('arduinoB1_d1')

#Time
t_d1 = df_d1['Time'].to_numpy()

#Distance 
tau_d1 = df_d1['Tau'].to_numpy()

# %%
t_d1, tau_d1
# Out:
# (array([     8032, 595600056, 595632076, 595664104, 595696132, 595728156,
#         595760184, 595792236, 595824306, 595856358, 595888400, 595920430,
#         595952452, 595984480, 596016522, 596048564, 596080598, 596112964,
#         596145320, 596177348, 596209374, 596241406, 596273436, 596305466,
#         596337490, 596369522, 596401552, 596433608, 596465686, 596497742,
#         596529768, 596561788, 596593840, 596625918, 596657990, 596690044,
#         596722070, 596754102, 596786124, 596818154, 596850178, 596882226,
#         596914280, 596946308, 596978332, 597010354, 597042384, 597074416,
#         597106468, 597138526, 597170556, 597202594, 597234630, 597266660,
#         597298688, 597330738, 597362794, 597394824, 597426882, 597458936,
#         597490964, 597523022, 597555098, 597587156, 597619214, 597651468,
#         597683704, 597715726, 597747782, 597779862, 597811936, 597844002,
#         597876070, 597908118, 597940142, 597972198, 598004266, 598036326,
#         598068406, 598100456, 598132506, 598164586, 598196666, 598228738,
#         598260820, 598292902, 598324962, 598357054, 598389132, 598421162,
#         598453210, 598485274, 598517342, 598549414, 598581476, 598613544,
#         598645608, 598677650, 598709706, 598741766, 598773810, 598805840,
#         598837882, 598869942, 598902022, 598934082, 598966118, 598998174,
#         599030220, 599062242, 599094268, 599126320, 599158372, 599190396,
#         599222452, 599254508, 599286526, 599318566, 599350608, 599382662,
#         599414708, 599446740, 599478774, 599510810, 599542852, 599574906,
#         599606986, 599639040, 599671074, 599703130, 599735202, 599767270,
#         599799326, 599831364, 599863398, 599895452, 599927526, 599959580,
#         599991614, 600023644, 600055690, 600087744, 600119774, 600151796,
#         600183824, 600215856, 600247886, 600279912, 600311966, 600344018,
#         600376054, 600408354, 600440658, 600472708, 600504762, 600536834,
#         600568914, 600600968, 600632994, 600665014, 600697044, 600729074,
#         600761098, 600793128, 600825182, 600857230, 600889252, 600921280,
#         600953310, 600985362, 601017418, 601049474, 601081530, 601113558,
#         601145592, 601177626, 601209654, 601241710, 601273790, 601305838,
#         601337868, 601369910, 601401952, 601433976, 601466004, 601498032,
#         601530058, 601562086, 601594116, 601626150, 601658174, 601690202,
#         601722230, 601754256, 601786290, 601818334, 601850390, 601882466,
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df_d2 = pd.read_csv('arduinoB1_d2')

#Time
t_d2 = df_d2['Time'].to_numpy()

#Distance 
tau_d2 = df_d2['Tau'].to_numpy()

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(1.03*10**9, 1.055*10**9)
plt.plot(t_d2[10:], tau_d2[10:], '.')
plt.show()

# %%
tau_d2_s = tau_d2/10**(6)
np.max(tau_d2_s)*c
np.mean(tau_d2_s[10:])*c
# Out:
# 0.27003131159595956

# %% [markdown]
# ### DISTANZA

# %%
d3 = 42 #cm

#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_d3', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df_d3 = pd.read_csv('arduinoB1_d3')

#Time
t_d3 = df_d3['Time'].to_numpy()

#Distance 
tau_d3 = df_d3['Tau'].to_numpy()

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(1.03*10**9, 1.055*10**9)
plt.plot(t_d3[10:], tau_d3[10:], '.')
plt.show()

# %%
tau_d3_s = tau_d3/10**(6)
np.max(tau_d3_s)*c
np.mean(tau_d3_s[10:])*c
# Out:
# 0.37688196197979795

# %% [markdown]
# ### DISTANZA

# %%
d4 = 58 #cm


#Port
port = '/dev/ttyACM0'
usb = serial.Serial(port)
f = open('arduinoB1_d4', 'w')
f.write('Time,Tau\n')

#Number of values you want to plot 
Nmax = 1000

n = 0
#While loop over n
while(n < Nmax):
    #Read data from the Serial Monitor
   
    arduino = usb.readline().rstrip()
    
    #If you want to print on terminal the values of t, tau and the relative number of n:
    #print(n, arduino.decode())
    
    #Print on file in format: time,tau
    f.write('{}\n'.format(arduino.decode()))
    n = n+1

# %%
#Dataframe with values read from serial monitor
df_d4 = pd.read_csv('arduinoB1_d4')

#Time
t_d4 = df_d4['Time'].to_numpy()

#Distance 
tau_d4 = df_d4['Tau'].to_numpy()

# %%
#Plot distance versus time
plt.title('OSCILLAZIONI MOLLA NEL TEMPO')
plt.xlabel('t[s]')
plt.ylabel('d')
#plt.xlim(1.03*10**9, 1.055*10**9)
plt.plot(t_d4[10:], tau_d4[10:], '.')
plt.show()

# %%
tau_d4_s = tau_d4/10**(6)
np.max(tau_d4_s)*c
np.mean(tau_d4_s[10:])*c
# Out:
# 0.5296076319191919
